# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshit6322/Machine-Learning/blob/main/2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=9
print(a)
# Out:
# 9

# %%
# !pip install matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np


x=np.array([0,10])
y=np.array([0,6])
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


x=np.array([0,10])
y=np.array([0,6])
plt.plot(x,y,'r*')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


x=np.array([0,4,2,6,1])
y=np.array([0,6,4,5,9])
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([0,6,4,5,9])
plt.plot(y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([0,6,4,5,9])
plt.plot(y , marker = 'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([0,6,4,5,9])
plt.plot(y,'r:o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([0,6,4,5,9])
plt.plot(y,'k-.o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([0,6,4,5,9])
plt.plot(y,'y--*')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([0,6,4,5,9])
plt.plot(y,'r-.o',ms=15)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([0,6,4,5,9])
plt.plot(y,'r-o',ms=15,mec='b')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([0,6,4,5,9])
plt.plot(y,'k-o',ms=15,mfc='y')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([0,6,4,5,9])
plt.plot(y,marker='o',ms=15,mec='r',mfc= 'r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([0,6,4,5,9])
plt.plot(y,marker='o',ms=15,mec='k',mfc= 'r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([0,6,4,5,9])
plt.plot(y,linestyle= 'dotted')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([0,6,4,5,9])
plt.plot(y,linestyle= 'dashed')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([0,6,4,5,9])
plt.plot(y,linewidth= 10)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


x1=np.array([0,4,2,6,1])
x2=np.array([0,6,4,5,9])
plt.plot(x1,'r',x2,'y')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 1, 10])
x2 = np.array([0, 1, 2, 3])
y2 = np.array([6, 2, 7, 11])
plt.xlabel("calorie")
plt.ylabel("day")
plt.title('smart watch')
plt.plot(x1, y1, x2, y2)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 1, 10])
x2 = np.array([0, 1, 2, 3])
y2 = np.array([6, 2, 7, 11])
plt.xlabel("calorie")
plt.ylabel("day")
plt.title('smart watch',loc='left')
plt.plot(x1, y1, x2, y2)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 1, 10])
x2 = np.array([0, 1, 2, 3])
y2 = np.array([6, 2, 7, 11])
plt.xlabel("calorie")
plt.ylabel("day")
plt.title('smart watch',loc='left')
plt.plot(x1, y1, x2, y2)
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 1, 10])
x2 = np.array([0, 1, 2, 3])
y2 = np.array([6, 2, 7, 11])
plt.xlabel("calorie")
plt.ylabel("day")
plt.title('smart watch',loc='left')
plt.plot(x1, y1, x2, y2)
plt.grid(axis='x')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 1, 10])
x2 = np.array([0, 1, 2, 3])
y2 = np.array([6, 2, 7, 11])
plt.xlabel("calorie")
plt.ylabel("day")
plt.title('smart watch',loc='left')
plt.plot(x1, y1, x2, y2)
plt.grid(axis='y')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 10])
y = np.array([240, 250, 260, 270, 0])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2,1,1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2,1,2)
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1,2,1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1,2,2)
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 4, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 4, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 4, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 4, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 4, 5)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 4, 6)
plt.plot(x,y)
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 4, 7)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 4, 8)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])


plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(4, 1, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(4, 1, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(4, 1, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(4, 1, 4)
plt.plot(x,y)



plt.show()
